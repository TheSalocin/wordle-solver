# %%
import json
from tqdm import tqdm

def is_wordle_compatible(data):
    if not "word" in data:
        return(False)
    word = data["word"]
    if len(word) != 5:
        return(False)
    if not word.isalpha():
        return(False)
    if not data["lang"] == "Deutsch":
        return(False)
    if data["pos"] == "name":
        return(False)
    return(True)       

wordset = set()
# data from https://kaikki.org/dictionary/rawdata.html
with open("../data/de-extract.jsonl", encoding="utf-8") as f:
    for line in tqdm(f):
        data = json.loads(line)
        if is_wordle_compatible(data):
            base_word = data["word"].lower()
            wordset.add(base_word)
# Out:
# 1291181it [00:20, 63059.32it/s]

# %%
wordset
# Out:
# {'burin',
#  'rösch',
#  'squaw',
#  'halme',
#  'schul',
#  'insvv',
#  'folia',
#  'eilet',
#  'doofe',
#  'bluse',
#  'ingas',
#  'alien',
#  'zähem',
#  'flaxt',
#  'sause',
#  'oreal',
#  'füget',
#  'dimer',
#  'übung',
#  'hüten',
#  'erbse',
#  'trend',
#  'schem',
#  'balzt',
#  'vrbas',
#  'rohre',
#  'banal',
#  'säfte',
#  'fickt',
#  'saudi',
#  'ysops',
#  'hehlt',
#  'unket',
#  'stetl',
#  'erhob',
#  'neppe',
#  'wallt',
#  'eumel',
#  'nudle',
#  'fifes',
#  'fahle',
#  'stupa',
#  'perms',
#  'poops',
#  'sauen',
#  'berme',
#  'raden',
#  'raube',
#  'sozia',
#  'umlad',
#  'jucke',
#  'henna',
#  'aktin',
#  'banat',
#  'groko',
#  'usanz',
#  'läppe',
#  'kohte',
#  'skuas',
#  'knaps',
#  'xylan',
#  'crêpe',
#  'colas',
#  'wimme',
#  'adens',
#  'abate',
#  'edles',
#  'krill',
#  'wache',
#  'silks',
#  'crows',
#  'muten',
#  'indio',
#  'balge',
#  'rahne',
#  'bemme',
#  'büdel',
#  'worts',
#  'erbin',
#  'senil',
#  'stege',
#  'pikas',
#  'äffen',
#  'hievt',
#  'dürre',
#  'mampf',
#  'geben',
#  'loder',
#  'zöger',
#  'gösch',
#  'ruine',
#  'mucke',
#  'brüht',
#  'umheg',
#  'ihrer',
#  'mongo',
#  'kubes',
#  'devot',
#  'volar',
#  'baums',
#  'durit',
#  'kräft',
#  'altle',
#  'möhre',
#  'ködre',
#  'praue',
#  'pomps',
#  'heide',
#  'velde',
#  'isais',
#  'rucke',
#  'würbt',
#  'eklet',
#  'öffis',
#  'worum',
#  'comic',
#  'aulos',
#  'senat',
#  'asern',
#  'wahns',
#  'zelot',
#  'laffe',
#  'ötzis',
#  'packt',
#  'sitas',
#  'tough',
#  'hülft',
#  'fäden',
#  'viehs',
#  'btmvv',
#  'opfre',
#  'hucke',
#  'feste',
#  'keese',
#  'abele',
#  'bräun',
#  'kelte',
#  'möbel',
#  'pneus',
#  'urans',
#  'kalis',
#  'lorke',
#  'aviär',
#  'paper',
#  'nigls',
#  'arkes',
#  'pofen',
#  'nahmt',
#  'gebär',
#  'exils',
#  'naugh',
#  'rambo',
#  'subvg',
#  'kiews',
#  'aguti',
#  'seide',
#  'gonen',
#  'gerbe',
#  'ossia',
#  'bowls',
#  'adden',
#  'hisst',
#  'mahre',
#  'krass',
#  'flagg',
#  'braue',
#  'erbau',
#  'stapf',
#  'picks',
#  'mater',
#  'widme',
#  'miaue',
#  'süßer',
#  'gigue',
#  'makak',
#  'snack',
#  'neffe',
#  'altai',
#  'panne',
#  'gucke',
#  'buses',
#  'loses',
#  'dahin',
#  'giere',
#  'stups',
#  'godln',
#  'plätt',
#  'bukst',
#  'lolas',
#  'maori',
#  'adler',
#  'ersja',
#  'songs',
#  'sücke',
#  'bimst',
#  'gayal',
#  'pivot',
#  'honks',
#  'gelte',
#  'säuft',
#  'dring',
#  'lotst',
#  'zweck',
#  'spatz',
#  'spezl',
#  'leier',
#  'larve',
#  'frost',
#  'sarge',
#  'verma',
#  'räson',
#  'ravte',
#  'jurke',
#  'flöße',
#  'mimst',
#  'walzt',
#  'torfe',
#  'wiyot',
#  'fallt',
#  'dohas',
#  'omuls',
#  'sulzt',
#  'phyla',
#  'hofes',
#  'südes',
#  'papal',
#  'böhme',
#  'delir',
#  'hukas',
#  'poles',
#  'hemds',
#  'papis',
#  'riols',
#  'human',
#  'skort',
#  'taben',
#  'biste',
#  'euere',
#  'groll',
#  'solis',
#  'denke',
#  'ebene',
#  'bucht',
#  'waage',
#  'seims',
#  'fstrg',
#  'süßes',
#  'raten',
#  'gabst',
#  'rdbms',
#  'films',
#  'duzen',
#  'askus',
#  'muses',
#  'scout',
#  'veden',
#  'räume',
#  'arnds',
#  'adult',
#  'beyen',
#  'knabe',
#  'anzus',
#  'pikes',
#  'nager',
#  'noobs',
#  'frett',
#  'steck',
#  'rojer',
#  'hunde',
#  'erben',
#  'wusch',
#  'haffs',
#  'knotz',
#  'davon',
#  'juxte',
#  'stoen',
#  'yamas',
#  'eshus',
#  'grede',
#  'beize',
#  'saldi',
#  'hyade',
#  'mätze',
#  'spiel',
#  'umtob',
#  'gouda',
#  'buges',
#  'bohnt',
#  'bolze',
#  'schiß',
#  'kross',
#  'regal',
#  'janas',
#  'taffe',
#  'lotse',
#  'pegel',
#  'zykas',
#  'lolli',
#  'turne',
#  'dötze',
#  'narde',
#  'foton',
#  'sünde',
#  'bäten',
#  'coupé',
#  'prägt',
#  'logge',
#  'geude',
#  'kreiß',
#  'söget',
#  'dekan',
#  'dagga',
#  'gegne',
#  'naben',
#  'kasko',
#  'zahle',
#  'büßer',
#  'stent',
#  'poppt',
#  'teich',
#  'senne',
#  'nerze',
#  'kerfe',
#  'ownen',
#  'teens',
#  'parst',
#  'fries',
#  'quill',
#  'braut',
#  'genas',
#  'terfs',
#  'harft',
#  'viert',
#  'tupis',
#  'monem',
#  'eräug',
#  'bafin',
#  'depot',
#  'surte',
#  'ostfw',
#  'polen',
#  'ultra',
#  'uvits',
#  'omaha',
#  'venen',
#  'buhen',
#  'maßen',
#  'flöze',
#  'befaß',
#  'sofas',
#  'karos',
#  'lecso',
#  'zahns',
#  'duvet',
#  'dopet',
#  'fünke',
#  'lölis',
#  'lernt',
#  'rhema',
#  'tagge',
#  'achse',
#  'limos',
#  'eughs',
#  'brumm',
#  'lofts',
#  'kaper',
#  'ritus',
#  'iktus',
#  'seren',
#  'äoler',
#  'party',
#  'wates',
#  'snöbe',
#  'cavas',
#  'asten',
#  'addax',
#  'berts',
#  'hieße',
#  'bello',
#  'stieb',
#  'eghgb',
#  'myrre',
#  'manne',
#  'dixis',
#  'anhob',
#  'koben',
#  'palen',
#  'tigre',
#  'zuriß',
#  'slimt',
#  'ölige',
#  'tapst',
#  'burka',
#  'grame',
#  'wuhrs',
#  'emden',
#  'armut',
#  'demse',
#  'gosst',
#  'kölns',
#  'risse',
#  'métis',
#  'lechi',
#  'wirst',
#  'rasch',
#  'feier',
#  'pofet',
#  'stags',
#  'vages',
#  'straß',
#  'senjs',
#  'aaset',
#  'dühne',
#  'raßen',
#  'knarz',
#  'krepp',
#  'helau',
#  'blähe',
#  'pfiff',
#  'mache',
#  'girre',
#  'farbe',
#  'eljen',
#  'rodet',
#  'gayas',
#  'thums',
#  'nahme',
#  'rente',
#  'valet',
#  'iftar',
#  'kehlt',
#  'pesos',
#  'renen',
#  'samos',
#  'mäßig',
#  'böten',
#  'allda',
#  'spüre',
#  'guffa',
#  'lyder',
#  'unrat',
#  'nares',
#  'curia',
#  'hacke',
#  'daune',
#  'album',
#  'mehle',
#  'koths',
#  'hürde',
#  'häßer',
#  'edler',
#  'kraut',
#  'esnas',
#  'wiens',
#  'ruins',
#  'essay',
#  'crews',
#  'abäße',
#  'sudor',
#  'sahen',
#  'wurzt',
#  'abtes',
#  'sisal',
#  'immen',
#  'krugs',
#  'drive',
#  'stele',
#  'ebits',
#  'telex',
#  'berls',
#  'tonus',
#  'treib',
#  'ratte',
#  'aaden',
#  'flieg',
#  'hypen',
#  'nords',
#  'kokse',
#  'gehrt',
#  'wotan',
#  'pfads',
#  'reiff',
#  'finge',
#  'amper',
#  'wedge',
#  'zopfe',
#  'ndswb',
#  'kripp',
#  'knitz',
#  'lasen',
#  'groov',
#  'dates',
#  'reche',
#  'scher',
#  'pogte',
#  'kommt',
#  'cairn',
#  'bussi',
#  'taken',
#  'erker',
#  'trieb',
#  'püffe',
#  'hussa',
#  'attus',
#  'helle',
#  'citys',
#  'typos',
#  'mokka',
#  'mathe',
#  'aksus',
#  'lobus',
#  'thore',
#  'foten',
#  'laubt',
#  'juxta',
#  'iller',
#  'bkatv',
#  'golds',
#  'hases',
#  'kikis',
#  'kraus',
#  'borns',
#  'ogefr',
#  'dängt',
#  'ermiß',
#  'ritte',
#  'hufet',
#  'ricke',
#  'humst',
#  'molke',
#  'fäule',
#  'dürft',
#  'rover',
#  'buhle',
#  'rotte',
#  'künde',
#  'azurn',
#  'harkt',
#  'zwick',
#  'teles',
#  'wolke',
#  'meder',
#  'arsch',
#  'amigo',
#  'unmut',
#  'kogis',
#  'lulus',
#  'thars',
#  'lyssa',
#  'träge',
#  'äppel',
#  'bring',
#  'draft',
#  'exend',
#  'beden',
#  'zäsur',
#  'zugab',
#  'bêten',
#  'sloop',
#  'autos',
#  'eises',
#  'morbi',
#  'poems',
#  'müsst',
#  'licht',
#  'sänge',
#  'hiebs',
#  'lahme',
#  'stuck',
#  'curry',
#  'leint',
#  'pütts',
#  'mandl',
#  'wurfs',
#  'kober',
#  'mosre',
#  'hasst',
#  'serös',
#  'täter',
#  'shirt',
#  'kämme',
#  'klaps',
#  'füllt',
#  'yärbe',
#  'leibe',
#  'sozen',
#  'limas',
#  'ivrit',
#  'fylke',
#  'fraßt',
#  'winke',
#  'thron',
#  'hopst',
#  'absah',
#  'biers',
#  'emirs',
#  'sägst',
#  'abtun',
#  'klipp',
#  'möven',
#  'sorgt',
#  'mohrs',
#  'pfund',
#  'betat',
#  'civil',
#  'bvger',
#  'tahin',
#  'funke',
#  'träne',
#  'pults',
#  'abbés',
#  'tunes',
#  'altöl',
#  'gönne',
#  'jabos',
#  'ghors',
#  'garne',
#  'gehle',
#  'ekelt',
#  'jogin',
#  'biwak',
#  'obste',
#  'velds',
#  'gäret',
#  'erlös',
#  'fusel',
#  'joche',
#  'glufe',
#  'lesen',
#  'fröne',
#  'spind',
#  'kabis',
#  'keile',
#  'legst',
#  'bytes',
#  'puppt',
#  'migda',
#  'eughe',
#  'wärme',
#  'belüg',
#  'agent',
#  'zaren',
#  'urass',
#  'brast',
#  'powre',
#  'zuzog',
#  'senke',
#  'mayas',
#  'narrt',
#  'übrig',
#  'beien',
#  'artel',
#  'krüll',
#  'taxte',
#  'hifel',
#  'laven',
#  'wogte',
#  'tusch',
#  'darin',
#  'dopes',
#  'anbiß',
#  'träme',
#  'wicks',
#  'seyet',
#  'welle',
#  'yuans',
#  'bravi',
#  'mofas',
#  'ruckt',
#  'labet',
#  'garet',
#  'gelds',
#  'birst',
#  'chemg',
#  'abend',
#  'losch',
#  'mäßet',
#  'zeits',
#  'schmu',
#  'molli',
#  'fixem',
#  'enden',
#  'nußöl',
#  'bovin',
#  'negir',
#  'erwob',
#  'umhat',
#  'malve',
#  'mèche',
#  'thein',
#  'kerze',
#  'ysope',
#  'wöhne',
#  'groom',
#  'atvfv',
#  'akens',
#  'katen',
#  'töret',
#  'urahn',
#  'hulks',
#  'kobre',
#  'dimme',
#  'mogle',
#  'rülps',
#  'sacht',
#  'krake',
#  'bösch',
#  'firme',
#  'tixos',
#  'aalig',
#  'allod',
#  'motor',
#  'jerez',
#  'orcas',
#  'narbt',
#  'tuppe',
#  'odlet',
#  'walöl',
#  'stuhl',
#  'zudem',
#  'metal',
#  'barde',
#  'maßes',
#  'stink',
#  'hufst',
#  'wopdv',
#  'ebros',
#  'säble',
#  'toste',
#  'mudra',
#  'bräme',
#  'krupp',
#  'farsi',
#  'umriß',
#  'ileen',
#  'gaset',
#  'rowdy',
#  'hämst',
#  'ankam',
#  'kämpf',
#  'leake',
#  'plins',
#  'hebel',
#  'rüber',
#  'fünfe',
#  'beeps',
#  'nehmt',
#  'konti',
#  'algol',
#  'berge',
#  'praßt',
#  'peset',
#  'enorm',
#  'brass',
#  'infam',
#  'kehrt',
#  'memme',
#  'grell',
#  'crack',
#  'saume',
#  'püree',
#  'batst',
#  'holen',
#  'hymne',
#  'pässe',
#  'melkt',
#  'polte',
#  'buhei',
#  'pudre',
#  'welke',
#  'färbt',
#  'betan',
#  'wicke',
#  'liefe',
#  'rebbe',
#  'abece',
#  'zulud',
#  'käsig',
#  'schas',
#  'metas',
#  'sohos',
#  'vögel',
#  'liier',
#  'blood',
#  'fülle',
#  'düfte',
#  'feile',
#  'kiepe',
#  'zahlt',
#  'uvala',
#  'bemas',
#  'trios',
#  'wehen',
#  'preie',
#  'blich',
#  'monat',
#  'sodas',
#  'höhst',
#  'torts',
#  'leine',
#  'chatt',
#  'imago',
#  'ebbst',
#  'vulva',
#  'hefig',
#  'prall',
#  'drift',
#  'crore',
#  'dafür',
#  'schah',
#  'jodle',
#  'syrte',
#  'polst',
#  'elfer',
#  'kämet',
#  'tülls',
#  'kotos',
#  'zwing',
#  'fonds',
#  'clubs',
#  'basse',
#  'minne',
#  'hecht',
#  'stola',
#  'mannt',
#  'werbe',
#  'halbe',
#  'mobil',
#  'loben',
#  'salpe',
#  'ruhet',
#  'gären',
#  'zirka',
#  'döset',
#  'anlaß',
#  'linst',
#  'wusts',
#  'zickt',
#  'unixe',
#  'helis',
#  'wöben',
#  'fielt',
#  'akyne',
#  'vakat',
#  'stehn',
#  'allzu',
#  'asyle',
#  'ether',
#  'luche',
#  'oblag',
#  'glimm',
#  'erleg',
#  'muffe',
#  'rangs',
#  'logik',
#  'doofi',
#  'inful',
#  'girrt',
#  'küble',
#  'bosel',
#  'eiert',
#  'erneu',
#  'stück',
#  'hörne',
#  'äsend',
#  'geher',
#  'engel',
#  'silur',
#  'kaons',
#  'rönnt',
#  'senst',
#  'hecke',
#  'jahns',
#  'still',
#  'zaune',
#  'cixis',
#  'disst',
#  'klang',
#  'braun',
#  'hüllt',
#  'rpflg',
#  'altem',
#  'düdos',
#  'assis',
#  'hasen',
#  'keine',
#  'beult',
#  'afbft',
#  'meson',
#  'bemba',
#  'wunde',
#  'hehls',
#  'trüge',
#  'kante',
#  'thune',
#  'küken',
#  'soren',
#  'spreu',
#  'darms',
#  'okras',
#  'grübt',
#  'nemis',
#  'ahmen',
#  'bahös',
#  'yeast',
#  'taros',
#  'iiasa',
#  'bufdi',
#  'saunt',
#  'lalas',
#  'heime',
#  'denar',
#  'vakua',
#  'heras',
#  'sanft',
#  'hißte',
#  'proll',
#  'passt',
#  'eddas',
#  'hauch',
#  'läufe',
#  'derbe',
#  'fahne',
#  'behos',
#  'taues',
#  'tamms',
#  'hotel',
#  'kopfs',
#  'femme',
#  'salto',
#  'acyls',
#  'russt',
#  'flopp',
#  'gasts',
#  'pesen',
#  'darrt',
#  'krümm',
#  'burlg',
#  'gands',
#  'reeps',
#  'ihres',
#  'funze',
#  'piven',
#  'waken',
#  'zaume',
#  'fiept',
#  'reets',
#  'asses',
#  'iglus',
#  'flows',
#  'tarne',
#  'sorge',
#  'rängt',
#  'anode',
#  'abort',
#  'eifer',
#  'paras',
#  'fehle',
#  'flurs',
#  'golfe',
#  'erleb',
#  'lahmt',
#  'kahle',
#  'inchs',
#  'tisch',
#  'ramas',
#  'auges',
#  'knopf',
#  'hicks',
#  'limes',
#  'krens',
#  'mariä',
#  'gellt',
#  'laban',
#  'brüsk',
#  'spurt',
#  'fönst',
#  'sägte',
#  'nahet',
#  'brock',
#  'exten',
#  'gabel',
#  'weber',
#  'safen',
#  'grubt',
#  'weibs',
#  'unser',
#  'ruwer',
#  'engem',
#  'grite',
#  'büßen',
#  'mixte',
#  'daris',
#  'büßet',
#  'kargo',
#  'tweef',
#  'käfig',
#  'swing',
#  'noble',
#  'tunet',
#  ...}

# %%
len(wordset) #TODO: seltsame wörter wie 'burin', 'rösch', 'schul', 'insvv'; nicht-grundformen in liste
# Out:
# 9587

# %%
with open("../data/de-extract.jsonl", encoding="utf-8") as f:
    for line in tqdm(f):
        data = json.loads(line)
        try:
            base_word = data["word"].lower()
        except: #errors happen when hard redirects
            print("word" in data)
            continue
        if base_word == "xaver":
            print(data)
# Out:
# 3424it [00:00, 11663.01it/s]
# False
# False
# {'word': 'Xaver', 'pos': 'name', 'pos_title': 'Vorname', 'lang_code': 'de', 'lang': 'Deutsch', 'senses': [{'glosses': ['männlicher Vorname'], 'examples': [{'text': 'Xaver ließ gestern wieder lange auf sich warten.', 'bold_text_offsets': [[0, 5]]}], 'sense_index': '1'}], 'translations': [{'sense': 'männlicher Vorname', 'word': 'Xabier', 'lang_code': 'eu', 'lang': 'Baskisch', 'sense_index': '1'}, {'sense': 'männlicher Vorname', 'word': 'Xavier', 'lang_code': 'en', 'lang': 'Englisch', 'sense_index': '1'}, {'sense': 'männlicher Vorname', 'word': 'Xavior', 'lang_code': 'en', 'lang': 'Englisch', 'sense_index': '1'}, {'sense': 'männlicher Vorname', 'word': 'Xzavier', 'lang_code': 'en', 'lang': 'Englisch', 'sense_index': '1'}, {'sense': 'männlicher Vorname', 'word': 'Zavier', 'lang_code': 'en', 'lang': 'Englisch', 'sense_index': '1'}, {'sense': 'männlicher Vorname', 'word': 'Xavier', 'lang_code': 'fr', 'lang': 'Französisch', 'sense_index': '1'}, {'sense': 'männlicher Vorname', 'word': 'Saverio', 'lang_code': 'it', 'lang': 'Italienisch', 'sense_index': '1'}, {'sense': 'männlicher Vorname', 'word': 'Xaverius', 'lang_code': 'la', 'lang': 'Latein', 'sense_index': '1'}, {'sense': 'männlicher Vorname', 'word': 'Ksawery', 'lang_code': 'pl', 'lang': 'Polnisch', 'sense_index': '1'}, {'sense': 'männlicher Vorname', 'word': 'Xawery', 'lang_code': 'pl', 'lang': 'Polnisch', 'sense_index': '1'}, {'sense': 'männlicher Vorname', 'word': 'Javier', 'lang_code': 'es', 'lang': 'Spanisch', 'sense_index': '1'}], 'sounds': [{'ipa': '[ˈksaːvɐ]'}, {'audio': 'De-Xaver.ogg', 'ogg_url': 'https://commons.wikimedia.org/wiki/Special:FilePath/De-Xaver.ogg', 'mp3_url': 'https://upload.wikimedia.org/wikipedia/commons/transcoded/c/c7/De-Xaver.ogg/De-Xaver.ogg.mp3'}, {'rhymes': 'aːvɐ'}], 'tags': ['masculine', 'noun'], 'categories': ['Anagramm sortiert (Deutsch)', 'Deutsch', 'Einträge mit Endreim (Deutsch)', 'Grundformeintrag (Deutsch)', 'Roter Audiolink', 'Rückläufige Wörterliste (Deutsch)', 'Rückläufige Wörterliste Grundformeintrag (Deutsch)', 'Substantiv (Deutsch)', 'Vorname (Deutsch)', 'Vorname m (Deutsch)', 'Wartung roter Link de-Vorname', 'Wiktionary:Audio-Datei', 'siehe auch'], 'etymology_texts': ['abgeleitet vom Namen der spanischen Burg Castillo de Javier, wo der heilige Francisco de Xavier (Franz Xaver) geboren wurde, als dessen Beiname Xaver ursprünglich nur bekannt war.'], 'forms': [{'form': 'Xavi', 'tags': ['abbreviation'], 'sense_index': '1'}, {'form': 'Xaverl', 'tags': ['diminutive'], 'sense_index': '1'}, {'form': 'Xava', 'tags': ['alternative'], 'sense_index': '1'}, {'form': 'Xaveria', 'tags': ['feminine'], 'sense_index': '1'}, {'form': 'Xaverine', 'tags': ['feminine'], 'sense_index': '1'}, {'form': 'Xaver', 'tags': ['nominative', 'singular'], 'article': 'der'}, {'form': 'Xavers', 'tags': ['nominative', 'plural'], 'article': 'die'}, {'form': 'Xaver', 'tags': ['genitive', 'singular'], 'article': 'des'}, {'form': 'Xavers', 'tags': ['genitive', 'singular'], 'article': 'des'}, {'form': 'Xavers', 'tags': ['genitive', 'singular']}, {'form': 'Xavers', 'tags': ['genitive', 'plural'], 'article': 'der'}, {'form': 'Xaver', 'tags': ['dative', 'singular'], 'article': 'dem'}, {'form': 'Xavers', 'tags': ['dative', 'plural'], 'article': 'den'}, {'form': 'Xaver', 'tags': ['accusative', 'singular'], 'article': 'den'}, {'form': 'Xavers', 'tags': ['accusative', 'plural'], 'article': 'die'}], 'hyphenations': [{'parts': ['Xa', 'ver']}]}
# 8968it [00:00, 16767.40it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 15059it [00:00, 19256.17it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 19624it [00:01, 21346.74it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 23954it [00:01, 20672.96it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 28478it [00:01, 21769.08it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 36966it [00:01, 34014.15it/s]
# False
# False
# False
# False
# False
# False
# 48550it [00:01, 46159.70it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 57342it [00:02, 39011.33it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 65086it [00:02, 31796.16it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 71469it [00:02, 28662.62it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 77100it [00:02, 26308.85it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 93606it [00:03, 43015.86it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 98049it [00:03, 40790.04it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 106057it [00:03, 31944.82it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 109435it [00:03, 29651.25it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 115669it [00:04, 29261.64it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 125555it [00:04, 31846.71it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 133803it [00:04, 36234.95it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 144700it [00:04, 46260.70it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 160749it [00:04, 63013.01it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 182779it [00:05, 86845.75it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 209379it [00:05, 109306.48it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 234928it [00:05, 106518.81it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 246093it [00:05, 71907.38it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 255095it [00:06, 58019.58it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 269330it [00:06, 57531.53it/s]
# False
# False
# False
# False
# False
# False
# 283665it [00:06, 63618.12it/s]
# False
# False
# False
# False
# False
# False
# False
# 298148it [00:06, 65703.40it/s]
# False
# False
# False
# False
# 320767it [00:07, 71952.02it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# 353223it [00:07, 78374.82it/s]
# False
# False
# False
# False
# False
# False
# False
# 377928it [00:07, 81198.10it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 393578it [00:08, 72201.76it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 400898it [00:08, 62858.79it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 413499it [00:08, 58808.04it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 427169it [00:08, 63435.99it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 441417it [00:08, 67175.80it/s]
# False
# False
# False
# 455134it [00:09, 67891.18it/s]
# False
# False
# 477113it [00:09, 71341.49it/s]
# False
# 508143it [00:09, 75342.61it/s]
# False
# False
# 536112it [00:10, 88237.51it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 563156it [00:10, 88596.63it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 583104it [00:10, 94754.72it/s]
# False
# False
# 614368it [00:10, 100375.88it/s]
# False
# False
# 634486it [00:11, 98297.63it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 661041it [00:11, 77540.12it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 683421it [00:11, 67539.80it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 696419it [00:12, 57264.02it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 718207it [00:12, 65013.94it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 731714it [00:12, 65503.94it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 745392it [00:12, 65853.72it/s]
# False
# False
# False
# False
# False
# 768075it [00:13, 69206.89it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 790645it [00:13, 67079.94it/s]
# False
# False
# False
# 804133it [00:13, 66233.32it/s]
# False
# False
# 817333it [00:13, 65101.54it/s]
# False
# False
# False
# False
# False
# False
# 844306it [00:14, 63445.40it/s]
# False
# False
# False
# 856845it [00:14, 61336.01it/s]
# False
# 901506it [00:15, 62709.28it/s]
# False
# False
# 914833it [00:15, 64725.51it/s]
# False
# False
# 948504it [00:15, 65140.12it/s]
# False
# False
# False
# False
# 961349it [00:16, 62947.19it/s]
# False
# False
# False
# False
# False
# False
# 974680it [00:16, 64776.48it/s]
# False
# False
# False
# False
# False
# False
# 987826it [00:16, 62331.49it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 1012797it [00:17, 60258.52it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 1031242it [00:17, 60936.77it/s]
# False
# False
# False
# False
# 1049368it [00:17, 59364.76it/s]
# False
# False
# 1061311it [00:17, 58923.74it/s]
# False
# False
# False
# False
# False
# False
# 1073217it [00:18, 58338.38it/s]
# False
# 1119492it [00:18, 68713.40it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 1133797it [00:18, 70147.01it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 1140934it [00:19, 70513.17it/s]
# False
# False
# False
# False
# 1163871it [00:19, 68574.71it/s]
# False
# False
# False
# False
# False
# False
# False
# 1185009it [00:19, 68779.62it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# 1206015it [00:20, 68174.92it/s]
# False
# False
# False
# 1221578it [00:20, 73027.68it/s]
# False
# False
# 1236395it [00:20, 73410.97it/s]
# False
# False
# False
# False
# False
# False
# 1273206it [00:20, 72881.89it/s]
# False
# False
# False
# False
# 1291181it [00:21, 61017.39it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
wordlist #TODO: duplicate words, words from other languages ('lang': 'Deutsch'), names ('word': 'Xaver', 'pos': 'name', 'pos_title': 'Vorname'), and words with special characters need to be removed
# Out:
# ['hallo',
#  'seria',
#  'seria',
#  'seria',
#  'seria',
#  'april',
#  'april',
#  'april',
#  'april',
#  'liebe',
#  'liebe',
#  'polen',
#  'polen',
#  'polen',
#  'polen',
#  'polen',
#  'krieg',
#  'feuer',
#  'japan',
#  'japan',
#  'japan',
#  'lunes',
#  'nihon',
#  'seite',
#  'kampf',
#  'licht',
#  'licht',
#  'woche',
#  'stein',
#  'stein',
#  'stein',
#  'stein',
#  'macht',
#  'vater',
#  'auto-',
#  'auto-',
#  'mushi',
#  'kleid',
#  'notiz',
#  'p. t.',
#  'tisch',
#  'bruch',
#  'bruch',
#  'rauch',
#  'rauch',
#  'fisch',
#  'fisch',
#  'fisch',
#  'apfel',
#  'apfel',
#  'maler',
#  'athen',
#  'musik',
#  'hilfe',
#  'murks',
#  'stand',
#  'schau',
#  'tasse',
#  'verbe',
#  'crude',
#  'ambi-',
#  'ambi-',
#  'faðir',
#  'faðir',
#  'faðir',
#  'zebra',
#  'zebra',
#  'zebra',
#  'zebra',
#  'stadt',
#  'figur',
#  'chlor',
#  'pferd',
#  'islam',
#  'islam',
#  'unagi',
#  'milbe',
#  'achat',
#  'nichi',
#  'agora',
#  'fuchs',
#  'fuchs',
#  'pomme',
#  'agate',
#  'agate',
#  'agate',
#  'agata',
#  'agata',
#  'agato',
#  'ágata',
#  'monat',
#  'mücke',
#  'mücke',
#  'mücke',
#  'nauru',
#  'nauru',
#  'biene',
#  'sehen',
#  'sehen',
#  'handy',
#  'hertz',
#  'inuit',
#  'mähre',
#  'mähre',
#  'stute',
#  'linux',
#  'olive',
#  'olive',
#  'olive',
#  'stahl',
#  'stahl',
#  'stahl',
#  'gabel',
#  'gabel',
#  'kohle',
#  'kohle',
#  'kohle',
#  'total',
#  'total',
#  'total',
#  'total',
#  'total',
#  'aalen',
#  'aalen',
#  'zelle',
#  'zelle',
#  'bänke',
#  'dodgy',
#  'paket',
#  'rappe',
#  'rappe',
#  'komma',
#  'brief',
#  'essen',
#  'essen',
#  'essen',
#  'blitz',
#  'aktie',
#  'stern',
#  'stern',
#  'wanze',
#  'wanze',
#  'vogel',
#  'vogel',
#  'sonne',
#  'frage',
#  'gehen',
#  'birne',
#  'joint',
#  'rigor',
#  'aller',
#  'aller',
#  'aller',
#  'regen',
#  'regen',
#  'regen',
#  'regen',
#  'stuhl',
#  'leben',
#  'aktiv',
#  'nagel',
#  'nagel',
#  'schön',
#  'schön',
#  'schon',
#  'schon',
#  'schon',
#  'schon',
#  'zunge',
#  'rasen',
#  'rasen',
#  'waffe',
#  'hecht',
#  'kugel',
#  'milch',
#  'knete',
#  'rubel',
#  'rubel',
#  'motor',
#  'kröte',
#  'hindi',
#  'katze',
#  'tafel',
#  'asche',
#  'asche',
#  'hasch',
#  'hasch',
#  'bauch',
#  'bauch',
#  'είμαι',
#  'novum',
#  'karhu',
#  'lintu',
#  'prost',
#  'prost',
#  'kader',
#  'lampe',
#  'lampe',
#  'υγεία',
#  'kirre',
#  'kirre',
#  'kirre',
#  'armee',
#  'manga',
#  'virus',
#  'staat',
#  'anime',
#  'huruf',
#  'hören',
#  'hören',
#  'zelot',
#  'lesen',
#  'krebs',
#  'haben',
#  'haben',
#  'aalen',
#  'aalen',
#  'aalen',
#  'aalen',
#  'aller',
#  'rasen',
#  'rasen',
#  'münze',
#  'z. b.',
#  'evtl.',
#  'sajak',
#  'hitam',
#  'paham',
#  'paham',
#  'olive',
#  'olive',
#  'blume',
#  'comic',
#  'bitte',
#  'adieu',
#  'adieu',
#  'adieu',
#  'ampel',
#  'kerze',
#  'achat',
#  'achat',
#  'säure',
#  'ideal',
#  'otaku',
#  'joint',
#  'joint',
#  'joint',
#  'joint',
#  'joint',
#  'durst',
#  'quant',
#  'stirn',
#  'niere',
#  'meter',
#  'start',
#  'engel',
#  'engel',
#  'engel',
#  'engel',
#  'kanne',
#  'polin',
#  'feind',
#  'cyrus',
#  'cyrus',
#  'roman',
#  'roman',
#  'roman',
#  'zwerg',
#  'zwerg',
#  'pekip',
#  'idiot',
#  'wurst',
#  'wurst',
#  'kraft',
#  'kraft',
#  'ideal',
#  'kerja',
#  'tubel',
#  'börse',
#  'faire',
#  'faire',
#  'faire',
#  'mopey',
#  'autor',
#  'zicke',
#  'macho',
#  'bilge',
#  'kotze',
#  'kotze',
#  'kotze',
#  'سيارة',
#  'سيارة',
#  'طائرة',
#  'pacht',
#  'nebel',
#  'nebel',
#  'nebel',
#  'nebel',
#  'kreuz',
#  'jesus',
#  'jesus',
#  'jesus',
#  'jesus',
#  'jesus',
#  'jesus',
#  'jesus',
#  'cross',
#  'cross',
#  'cross',
#  'cross',
#  'solar',
#  'solar',
#  'solar',
#  'solar',
#  'neger',
#  'neger',
#  'ratte',
#  'sugar',
#  'sugar',
#  'index',
#  'bange',
#  'aasen',
#  'linie',
#  'hasel',
#  'hasel',
#  'hasel',
#  'töten',
#  'insel',
#  'pizza',
#  'sport',
#  'köter',
#  'naked',
#  'äbich',
#  'aktiv',
#  'regie',
#  'seele',
#  'simse',
#  'sechs',
#  'müßig',
#  'sorge',
#  'adler',
#  'adler',
#  'adler',
#  'adler',
#  'adler',
#  'zwölf',
#  'reden',
#  'reden',
#  'blüte',
#  'immer',
#  'breit',
#  'breit',
#  'abend',
#  'abend',
#  'abend',
#  'hymne',
#  'palme',
#  'pampa',
#  'spint',
#  'panda',
#  'panda',
#  'spind',
#  'panik',
#  'abart',
#  'abart',
#  'panne',
#  'panne',
#  'döner',
#  'schuh',
#  'preis',
#  'enorm',
#  'enorm',
#  'stolz',
#  'mauer',
#  'mauer',
#  'penis',
#  'fotze',
#  'busen',
#  'brust',
#  'titte',
#  'hoden',
#  'hoden',
#  'backe',
#  'backe',
#  'flöte',
#  'magen',
#  'organ',
#  'spiel',
#  'birke',
#  'birke',
#  'farbe',
#  'buche',
#  'buche',
#  'firma',
#  'arsch',
#  'zool.',
#  'eiche',
#  'linde',
#  'simon',
#  'simon',
#  'bayr.',
#  'nativ',
#  'a. d.',
#  'hist.',
#  'allg.',
#  'aküfi',
#  'a. m.',
#  'a. o.',
#  'schau',
#  'schau',
#  'licht',
#  'licht',
#  'licht',
#  'licht',
#  'amtl.',
#  'iron.',
#  'aufl.',
#  'esche',
#  'tulpe',
#  'aaron',
#  'aaron',
#  'aaron',
#  'aaron',
#  'aaron',
#  'aaron',
#  'aaron',
#  'aaron',
#  'aaron',
#  'achim',
#  'achim',
#  'beil.',
#  'betr.',
#  'brit.',
#  'salam',
#  'abort',
#  'abort',
#  'abort',
#  'b. w.',
#  'bzgl.',
#  'adolf',
#  'adolf',
#  'adolf',
#  'adolf',
#  'neffe',
#  'neffe',
#  'neffe',
#  'neffe',
#  'onkel',
#  'tante',
#  'ahmad',
#  'd. ä.',
#  'decir',
#  'decir',
#  'tanne',
#  'afaik',
#  'afaik',
#  'teuer',
#  'd. h.',
#  'd. i.',
#  'dipl.',
#  'd. j.',
#  'd. m.',
#  'd. o.',
#  'dtzd.',
#  'e. h.',
#  'ehem.',
#  'eidg.',
#  'engl.',
#  'e. v.',
#  'expl.',
#  'folg.',
#  'alain',
#  'sehne',
#  'strom',
#  'felix',
#  'xaver',
#  'xenia',
#  'xylon',
#  'dolos',
#  'boden',
#  'kunst',
#  'mhdt.',
#  'gebr.',
#  'u. z.',
#  'gegr.',
#  'gest.',
#  'tirol',
#  'alban',
#  'apang',
#  'atlas',
#  'atlas',
#  'atlas',
#  'atlas',
#  'atlas',
#  'atlas',
#  'atlas',
#  'mamma',
#  'mamma',
#  'mamma',
#  'mamma',
#  'mamma',
#  'pabbi',
#  'geben',
#  'ggfs.',
#  'h. c.',
#  'hins.',
#  'hrsg.',
#  'i. a.',
#  'i. b.',
#  'ital.',
#  'amöbe',
#  'cache',
#  'dalur',
#  'dalur',
#  'vetur',
#  'luchs',
#  'luchs',
#  'bóndi',
#  'tunga',
#  'tunga',
#  'tunga',
#  'lilja',
#  'i. d.',
#  'i. h.',
#  'venus',
#  'venus',
#  'venus',
#  'pluto',
#  'pluto',
#  'pluto',
#  'pluto',
#  'ayimo',
#  'animo',
#  'animo',
#  'animo',
#  'ayima',
#  'aduma',
#  'arobu',
#  'ayubu',
#  'aewer',
#  'inkl.',
#  'incl.',
#  'i. r.',
#  'i. v.',
#  'jhdt.',
#  'kath.',
#  'aðall',
#  'beruf',
#  'idiom',
#  'helau',
#  'klein',
#  'klein',
#  'datum',
#  'lunga',
#  'lunga',
#  'ثعبان',
#  'daten',
#  'daten',
#  'firma',
#  'firma',
#  'firma',
#  'firma',
#  'firma',
#  'firma',
#  'firma',
#  'firma',
#  'フランス語',
#  'd-zug',
#  'móðir',
#  'móðir',
#  'fuzzi',
#  'hölle',
#  'fjall',
#  'fjall',
#  'erzg.',
#  'welli',
#  'punkt',
#  'donau',
#  'petra',
#  'petra',
#  'petra',
#  'lfrg.',
#  'luth.',
#  'm. e.',
#  'mill.',
#  'mitw.',
#  'möbl.',
#  'm. w.',
#  'mwst.',
#  'nchf.',
#  'näml.',
#  'n. n.',
#  'wolke',
#  'bache',
#  'bache',
#  'eidam',
#  'fluss',
#  'sirup',
#  'mainz',
#  'chile',
#  'chile',
#  'chile',
#  'chile',
#  'bair.',
#  'küche',
#  'zitat',
#  'kenia',
#  'kenia',
#  'kelt.',
#  'minsk',
#  'minsk',
#  'sofia',
#  'sofia',
#  'sofia',
#  'sofia',
#  'kubus',
#  'beton',
#  'süßw.',
#  'katar',
#  'crack',
#  'crack',
#  'kombi',
#  'kombi',
#  'süden',
#  'osten',
#  'osten',
#  'o. ä.',
#  'o. ä.',
#  'o. b.',
#  'offz.',
#  'orig.',
#  'orth.',
#  'p. a.',
#  'pers.',
#  'prof.',
#  'resp.',
#  'r.-k.',
#  's. o.',
#  's. u.',
#  'beidl',
#  'stoff',
#  'hexer',
#  'russ.',
#  'sturm',
#  'sturm',
#  'natel',
#  'piano',
#  'piano',
#  'piano',
#  'piano',
#  'piano',
#  'piano',
#  'piano',
#  'piano',
#  'piano',
#  'piano',
#  'forte',
#  'forte',
#  'forte',
#  'forte',
#  'forte',
#  'kvæði',
#  'kvæði',
#  'jeppi',
#  'gemsi',
#  'eonia',
#  'tölva',
#  'glück',
#  'glück',
#  'veður',
#  'veður',
#  'blues',
#  'molen',
#  'hoofd',
#  'trein',
#  'meise',
#  'vagil',
#  'lurch',
#  'lurch',
#  'korak',
#  'mesto',
#  'liter',
#  'kolač',
#  'utf-8',
#  'cibus',
#  'saxum',
#  'capra',
#  'capra',
#  'lupus',
#  'hagel',
#  'フランス人',
#  'adres',
#  'adres',
#  'adres',
#  'karte',
#  'mönch',
#  'mönch',
#  'mönch',
#  'pizzo',
#  'kolja',
#  'zelus',
#  'lemma',
#  'lokal',
#  'lokal',
#  'lokal',
#  'olsch',
#  'olsza',
#  'vokal',
#  'spatz',
#  'erika',
#  'erika',
#  'xenon',
#  'allee',
#  'biwak',
#  'dunst',
#  'blase',
#  'blase',
#  'ahorn',
#  'ülmen',
#  'fähig',
#  'manus',
#  'manus',
#  'lacus',
#  'arcus',
#  'nager',
#  'boîte',
#  'boîte',
#  'platz',
#  'ziege',
#  'stdl.',
#  'asien',
#  'stud.',
#  'tägl.',
#  'beute',
#  'beute',
#  'klamm',
#  'wafer',
#  'cotxe',
#  'baden',
#  'baden',
#  'baden',
#  'baden',
#  'heint',
#  'welle',
#  'welle',
#  'welle',
#  'geest',
#  'kurve',
#  'minut',
#  'minut',
#  'minut',
#  'minut',
#  'minut',
#  'minut',
#  'segon',
#  'segon',
#  'leben',
#  'edukt',
#  'kalla',
#  'kalla',
#  'kalla',
#  'segja',
#  'kaupa',
#  'horfa',
#  'fubar',
#  'stift',
#  'stift',
#  'stift',
#  'stift',
#  'spass',
#  'wicht',
#  'wicht',
#  'linse',
#  'gener',
#  'abril',
#  'abril',
#  'abril',
#  'abril',
#  'abril',
#  'abril',
#  'agost',
#  'agost',
#  'deuce',
#  'leita',
#  'öskra',
#  'elska',
#  'elska',
#  'kyssa',
#  'kyssa',
#  'nelke',
#  'galan',
#  'sassy',
#  'verða',
#  'verða',
#  'abgas',
#  'geist',
#  'rinde',
#  'traum',
#  'oheim',
#  'estiu',
#  'estiu',
#  'hiems',
#  'plagi',
#  'suppe',
#  'ràbia',
#  'sonar',
#  'viril',
#  'wüste',
#  'wüste',
#  'tiger',
#  'amsel',
#  'tucke',
#  'sechs',
#  'sechs',
#  'zwölf',
#  'abric',
#  'abric',
#  'orzeł',
#  'dudek',
#  'dudek',
#  'dudek',
#  'alois',
#  'weihe',
#  'weihe',
#  'putih',
#  'chien',
#  'kreis',
#  'boson',
#  'horse',
#  'horse',
#  'merah',
#  'hijau',
#  'kecil',
#  'besar',
#  'mahal',
#  'murah',
#  'essig',
#  'essig',
#  'sauer',
#  'sauer',
#  'sauer',
#  'satte',
#  'nicht',
#  'nicht',
#  'mulde',
#  'mulde',
#  'cuina',
#  'tendó',
#  'salat',
#  'edikt',
#  'tight',
#  'ägide',
#  'beere',
#  'jolle',
#  'kokos',
#  'pfahl',
#  'pfahl',
#  'pfahl',
#  'affix',
#  'einer',
#  'einer',
#  'einer',
#  'einem',
#  'einem',
#  'einem',
#  'einen',
#  'einen',
#  'einen',
#  'einen',
#  'eines',
#  'eines',
#  'eines',
#  'kurwa',
#  'kurwa',
#  'viisi',
#  'modus',
#  'dativ',
#  'colze',
#  'cuixa',
#  'tíbia',
#  'tíbia',
#  'ungla',
#  'zivil',
#  'chääs',
#  'debil',
#  'loqui',
#  'dacha',
#  'среда',
#  'среда',
#  'sabio',
#  'sabio',
#  'ojalá',
#  'noche',
#  'cielo',
#  'cielo',
#  'cielo',
#  'terre',
#  'terre',
#  'paris',
#  'paris',
#  'paris',
#  'paris',
#  'paris',
#  'węgry',
#  'glans',
#  'glans',
#  'aback',
#  'aback',
#  'kotka',
#  'kotka',
#  'vikar',
#  'metge',
#  'angst',
#  'hallo',
#  'mitjó',
#  'remis',
#  'quasi',
#  'quasi',
#  'quasi',
#  'quasi',
#  'quasi',
#  'quasi',
#  'kasus',
#  'środa',
#  'mäzen',
#  'mager',
#  'mager',
#  'kurie',
#  'sumpf',
#  'michi',
#  'michi',
#  'geige',
#  'fiðla',
#  'álfur',
#  'ozean',
#  'moros',
#  'skema',
#  'kraut',
#  'kraut',
#  'kraut',
#  'falke',
#  'jeudi',
#  'lundi',
#  'lundi',
#  'mardi',
#  'papst',
#  'sonja',
#  'hocke',
#  'hocke',
#  'orang',
#  'ownen',
#  'wodka',
#  'udire',
#  'braun',
#  'husse',
#  'bauer',
#  'bauer',
#  'bauer',
#  'bauer',
#  'tempo',
#  'tempo',
#  'tempo',
#  'fleet',
#  'essen',
#  'essen',
#  'essen',
#  'essen',
#  'sinah',
#  'björn',
#  'hemi-',
#  'hemi-',
#  'terra',
#  'terra',
#  'terra',
#  'terra',
#  'terra',
#  'votum',
#  'เดือน',
#  'antik',
#  'antik',
#  'antik',
#  'hecke',
#  'hecke',
#  'hurra',
#  'dinar',
#  'dinar',
#  'sopar',
#  'sopar',
#  'summe',
#  'suche',
#  'fidel',
#  'sagen',
#  'a. a.',
#  'nutte',
#  'ignis',
#  'abrin',
#  'ಕನ್ನಡ',
#  'بھارت',
#  'apple',
#  'appel',
#  ...]

# %%
len(wordlist)
# Out:
# 46925
